# %%
# %sql
CREATE CATALOG IF NOT EXISTS  ecommerce_lakehouse_project;

CREATE SCHEMA IF NOT EXISTS ecommerce_lakehouse_project.bronze;
CREATE SCHEMA IF NOT EXISTS ecommerce_lakehouse_project.silver;
CREATE SCHEMA IF NOT EXISTS ecommerce_lakehouse_project.gold;
